# %% [markdown]
# <p><b>Exercise 1: Nested for loop for plate coordinates</b></p>
# <p>You are given the list of letters. Use nested loop, this list and python <code>range()</code> function to construct the list of the wells in 96 well plate.</p><p>The resultant list should contain all wells:</p>
# <p><code>['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1', 'A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2', 'A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3', 'A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4', 'A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5', 'A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6', 'A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7', 'A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8', 'A9', 'B9', 'C9', 'D9', 'E9', 'F9', 'G9', 'H9', 'A10', 'B10', 'C10', 'D10', 'E10', 'F10', 'G10', 'H10', 'A11', 'B11', 'C11', 'D11', 'E11', 'F11', 'G11', 'H11', 'A12', 'B12', 'C12', 'D12', 'E12', 'F12', 'G12', 'H12']</code></p>

# %%
list_letters = ["A", "B", "C", "D", "E", "F", "G", "H"]

# %% [markdown]
# <b> Exercise 2 </b> - Given the dictionaries of the days and their order numbers use input statement to make a program which:
# - Asks a user to input the day of the week (eg. wednesday).
# - prints out what day will be next day after the day that was provided by user.
# - Account for the situation when user makes a mistake and inputs day name incorrectly.
#
# <br> <b> Hint: </b> you will need to use if statements. </br>

# %%
Dictionary_days_numbers = {
    "Monday": 1,
    "Tuesday": 2,
    "Wednesday": 3,
    "Thursday": 4,
    "Friday": 5,
    "Saturday": 6,
    "Sunday": 7
}

numbers_days = {
    1: "Monday",
    2: "Tuesday",
    3: "Wednesday",
    4: "Thursday",
    5: "Friday",
    6: "Saturday",
    7: "Sunday"
}

# %%
# put your code here

# %% [markdown]
# <p><b>Exercise 3:</b></p>

# %% [markdown]
# <p>Taking in account all the things you learned in your previous lessons. Build a program that: </p>
# <ol><li>Accepts the protein sequence as input.</li>
# <li>Filters out non-amino acid characters out of it. </li>
# <li>Calculates the molecular weight of the user provided protein</li></ol>
# <p>Note: On the C-terminus on the there is one molecule of water. </p>
# <p>The dictionary of the dehydrated molecular weights is provided below:</p>

# %%
amino_acid_weights = {
    'A': 71.03711,  # Alanine
    'R': 156.10111, # Arginine
    'N': 114.04293, # Asparagine
    'D': 115.02694, # Aspartic acid
    'C': 103.00919, # Cysteine
    'E': 129.04259, # Glutamic acid
    'Q': 128.05858, # Glutamine
    'G': 57.02146,  # Glycine
    'H': 137.05891, # Histidine
    'I': 113.08406, # Isoleucine
    'L': 113.08406, # Leucine
    'K': 128.09496, # Lysine
    'M': 131.04049, # Methionine
    'F': 147.06841, # Phenylalanine
    'P': 97.05276,  # Proline
    'S': 87.03203,  # Serine
    'T': 101.04768, # Threonine
    'W': 186.07931, # Tryptophan
    'Y': 163.06333, # Tyrosine
    'V': 99.06841   # Valine
}
